# %%
from roboflow import Roboflow
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

rf = Roboflow(api_key="uMUVjvL3wu5Jz1Y3sq4J")
project = rf.workspace("bao-bao-3gkoq").project("vocimgs")
version = project.version(1)
model = version.model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to C:\Users\Tartiflettopolys\Desktop\im_a_folder\Perso\Prog\Python\Hackathon\Models\myModel in yolov7pytorch:: 100%|██████████| 10410/10410 [00:04<00:00, 2122.51it/s]

# %%
def predict(image_path:str) -> dict:
    img = mpimg.imread(image_path)
    result = model.predict(img, confidence=40, overlap=30).json()
    for i in range(0, len(result["predictions"])):
        result["predictions"][i].pop("image_path")
    return result["predictions"]


image_path = "C:\\Users\\Tartiflettopolys\\Desktop\\im_a_folder\\Perso\\Prog\\Python\\Hackathon\\Datasets\\VOCImgs-5\\test\\000621_jpg.rf.f13da7545cccffcbeb17443a611b82cd.jpg"
image_path2 = "C:\\Users\\Tartiflettopolys\\Desktop\\im_a_folder\\Perso\\Prog\\Python\\Hackathon\\Datasets\\Autonomous-Garbage-Collector-Boat-1\\test\\IMG_20230205_073636_634_jpg.rf.2b2c4ff99b57de0e80f48020dffdac89.jpg"
img = mpimg.imread(image_path2)
plt.imshow(img)

print(predict(image_path2))
# Out:
# [{'x': 177.5, 'y': 385.0, 'width': 161.0, 'height': 174.0, 'confidence': 0.42758893966674805, 'class': 'bottle', 'class_id': 1, 'detection_id': 'a4135afc-8618-48d9-b385-51e630ae4279', 'prediction_type': 'ObjectDetectionModel'}]

# %%
# print(dir(type(model)))

model_path:str = "C:\\Users\\Tartiflettopolys\\Desktop\\im_a_folder\\Perso\\Prog\\Python\\Hackathon\\Models\\baseModel.pt"
print(model.__api_key)
model.download("pt", model_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 4
#       1 # print(dir(type(model)))
#       3 model_path:str = "C:\\Users\\Tartiflettopolys\\Desktop\\im_a_folder\\Perso\\Prog\\Python\\Hackathon\\Models\\baseModel.pt"
# ----> 4 print(model.__api_key)
#       5 model.download("pt", model_path)
#
# AttributeError: 'ObjectDetectionModel' object has no attribute '__api_key'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.device(device)
